# %% [markdown]
# # 01 — Load data
#
# Load the sample African population dataset and inspect its shape.
#
# *Français : charger le jeu de données démographique africain et inspecter sa forme.*

# %%
import sys
from pathlib import Path

sys.path.insert(0, str(Path.cwd().parent))

from src.utils import load_csv

df = load_csv("../data/raw/population_africa_sample.csv")
print(df.shape)
df.head()

# %%
df.info()

# %%
df.describe()
